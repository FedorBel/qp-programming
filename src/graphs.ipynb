# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# if using a jupyter notebook
# %matplotlib inline

# %%
def f(x1, x2):
    return x1 ** 2 - x2 ** 2

x1 = np.arange(0, 10, 0.1)
x2 = np.arange(0, 10, 0.1)
f_ar = np.zeros( (x1.size, x2.size) )
counter_y = 0

for x1_i in x1:
    counter_x = 0
    for x2_i in x2:
        f_ar[counter_x, counter_y] = f(x1_i, x2_i)
        counter_x += 1
    counter_y += 1

X, Y = np.meshgrid(x1, x2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, f_ar)

# %%
plt.contourf(x1, x2, f_ar)
plt.colorbar()
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %%
import osqp
import numpy as np
from scipy import sparse

# Define problem data
P = sparse.csc_matrix([[1, 0], [0, -1]]) * 2
# q = np.array([-5, -6])
# A = sparse.csc_matrix([[1, -1], [-0.3, -1], [1, 0], [0, 1], [1, 0]])
# l = np.array([-np.inf, -np.inf, 0, 0, 5])
# u = np.array([-2, -8, 10, 10, 5])

# Create an OSQP object
prob = osqp.OSQP()

# Setup workspace and change alpha parameter
# prob.setup(P, q)
prob.setup(P)

# Solve problem
res = prob.solve()
print(res.x)
# Out:
# ERROR in LDL_factor: Error in KKT matrix LDL factorization when computing the nonzero elements. The problem seems to be non-convex
# ERROR in osqp_setup: KKT matrix factorization.
# The problem seems to be non-convex.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 17
#      13 prob = osqp.OSQP()
#      15 # Setup workspace and change alpha parameter
#      16 # prob.setup(P, q)
# ---> 17 prob.setup(P)
#      19 # Solve problem
#      20 res = prob.solve()
#
# File ~/.local/lib/python3.8/site-packages/osqp/interface.py:37, in OSQP.setup(self, P, q, A, l, u, **settings)
#      34 self._derivative_cache = {'P': P, 'q': q, 'A': A, 'l': l, 'u': u}
#      36 unpacked_data, settings = utils.prepare_data(P, q, A, l, u, **settings)
# ---> 37 self._model.setup(*unpacked_data, **settings)
#
# ValueError: Workspace allocation error!
